# %%
# Arquivo para visualizar apenas os dados tratados.

# %%
import pandas as pd

# %%
processed_data = pd.read_excel('../../database/financial.xlsx')
processed_data.head()
# Out:
#           segment  country    product discount_band  units_sold  \
# 0      Government   Canada    Montana          High         200
# 1  Small Business  Germany  Carretera           Low         214
# 2  Small Business  Germany        VTT           Low         214
# 3       Midmarket   Canada      Paseo           Low         218
# 4      Government  Germany      Paseo          High         241
#
#    manufacturing_price  sale_price  gross_sales  discounts    sales     cogs  \
# 0                    5         350      70000.0     9800.0  60200.0  52000.0
# 1                    3         300      64200.0     1284.0  62916.0  53500.0
# 2                  250         300      64200.0     1284.0  62916.0  53500.0
# 3                   10          15       3270.0      130.8   3139.2   2180.0
# 4                   10          20       4820.0      482.0   4338.0   2410.0
#
#    profit       date  month_number month_name  year
# 0  8200.0 2014-05-01             5        May  2014
# ...

# %%
display(processed_data['country'].unique())
display(processed_data['product'].unique())
display(processed_data['discount_band'].unique())
display(processed_data['units_sold'].unique())
display(processed_data['manufacturing_price'].unique())
display(processed_data['sale_price'].unique())
# Out:
# array(['Canada', 'Germany', 'Mexico', 'United States of America',
#        'France'], dtype=object)
# array(['Montana', 'Carretera', 'VTT', 'Paseo', 'Velo', 'Amarilla'],
#       dtype=object)
# array(['High', 'Low', 'Medium', 'No Discount'], dtype=object)
# array([ 200,  214,  218,  241,  245,  257,  259,  260,  263,  266,  267,
#         269,  270,  274,  278,  280,  292,  293,  306,  321,  322,  330,
#         334,  341,  344,  345,  349,  357,  360,  362,  367,  380,  381,
#         384,  386,  388,  410,  422,  432,  436,  442,  448,  472,  488,
#         490,  492,  494,  500,  510,  521,  544,  546,  547,  549,  552,
#         554,  555,  562,  567,  570,  571,  574,  579,  588,  591,  598,
#         602,  604,  606,  609,  615,  623,  635,  639,  641,  645,  655,
#         660,  662,  663,  671,  677,  678,  681,  689,  690,  700,  704,
#         707,  708,  711,  720,  723,  727,  736,  742,  747,  766,  787,
# ...
